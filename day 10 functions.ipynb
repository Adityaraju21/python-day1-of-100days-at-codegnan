# %%
## list properties
# list elements access by using index poositions
lst = [10,2,4,4.534, 'hi' , 'hello']
print(lst[2])
print(lst[-3])
print(lst[2:])
# Out:
# 4
# 4.534
# [4, 4.534, 'hi', 'hello']

# %%
lst = [1,2,3,40,'hi' , 'hello']
lst [0] = 100
print (lst)
# Out:
# [100, 2, 3, 40, 'hi', 'hello']

# %%
#string is immutable
s = 'srinu'
s[0] ='z'
print (s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #string is immutable
#       2 s = 'srinu'
# ----> 3 s[0] ='z'
#       4 print (s)
#
# TypeError: 'str' object does not support item assignment

# %%
# nesteed list element access
lst = [1,2,3,4,[10,30,50, ['a','b','c']] ,29,1,2,3]
print(lst[4])
print(lst[4][1])
print(lst[4][3][2])
# Out:
# [10, 30, 50, ['a', 'b', 'c']]
# 30
# c

# %%
# reading list of elements from user
l = list(map(int, input().split()))
print(type(1), 1)
# Out:
#  1234
# <class 'int'> 1

# %%
# reading list of elements from user
l = list(map(int, input().split()))
print(type(1), 1)
# Out:
#  1 2 3 2.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # reading list of elements from user
# ----> 2 l = list(map(int, input().split()))
#       3 print(type(1), 1)
#
# ValueError: invalid literal for int() with base 10: '2.5'

# %% [markdown]
# # list = [1,2,3,4,5]
# # res = [ 2, 2.5, 4, 4.5, 6]
# list = list(map(int, input().split()))
# for range of 0

# %%
# read list of numberr and if number is even odd 0.5 and if number is odd odd 1
lst = [1,2,3,4,5]
res = [2, 2.5, 4, 4.5, 6]
lst = list(map(int, input().split()))
for i in range(0, len(lst)):
    if lst[1] % 2:
        lst[1] = lst[1] + 1
    else:
        lst[1] += 0.5
print(lst)
# Out:
#  1 2 3 4 5
# [1, 6.5, 3, 4, 5]
